# %% [markdown]
# # Validation of jupyter inner images with fastpages
# - show_tags: true
# - toc: true
# - branch: master
# - badges: false
# - comments: true
# - categories: [blog, fastpages]

# %% [markdown]
# When this page will appear it will mean this feature has been implemented!
#
# ![image.png](attachment:image.png)
